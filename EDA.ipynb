# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file with tab delimiter
data = pd.read_csv('Gaming_Data.csv', delimiter='\t')

# Strip leading/trailing spaces from column names
data.columns = data.columns.str.strip()

# Inspect column names again
print(data.columns)
# Out:
# Index(['Label', 'Time (s)', 'Sound pressure level (dB)', 'Music', 'Win',
#        'Heart rate(bpm)', 'Emotional state'],
#       dtype='object')

# %%
print(data.columns)
# Out:
# Index(['Label', 'Time (s)', 'Sound pressure level (dB)', 'Music', 'Win',
#        'Heart rate(bpm)', 'Emotional state'],
#       dtype='object')

# %%
# Summary statistics
print(data.describe())
# Out:
#               Label      Time (s)  Sound pressure level (dB)         Music  \
# count  25092.000000  25092.000000               24852.000000  25092.000000
# mean       2.642077    310.679885                 -55.787633      0.611549
# std        1.356158    211.389745                   8.559648      0.487408
# min        1.000000      0.000000                 -74.487855      0.000000
# 25%        1.000000    132.518004                 -61.800000      0.000000
# 50%        3.000000    280.598191                 -57.400000      1.000000
# 75%        4.000000    463.025101                 -50.900000      1.000000
# max        5.000000    825.725933                  -7.980000      1.000000
#
#            Win  Heart rate(bpm)
# count  25092.0     25092.000000
# mean       1.0        83.985812
# std        0.0         5.788016
# min        1.0        70.000000
# 25%        1.0        80.000000
# 50%        1.0        85.000000
# 75%        1.0        88.000000
# max        1.0        93.000000

# %%
# Data types
print(data.dtypes)

# Missing values
print(data.isnull().sum())
# Out:
# Label                          int64
# Time (s)                     float64
# Sound pressure level (dB)    float64
# Music                          int64
# Win                            int64
# Heart rate(bpm)                int64
# Emotional state               object
# dtype: object
# Label                          0
# Time (s)                       0
# Sound pressure level (dB)    240
# Music                          0
# Win                            0
# Heart rate(bpm)                0
# Emotional state                0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file with tab delimiter
data = pd.read_csv('Gaming_Data.csv', delimiter='\t')

# Strip leading/trailing spaces from column names
data.columns = data.columns.str.strip()

# %%
# List of numerical columns
numerical_cols = ['Time (s)', 'Sound pressure level (dB)', 'Heart rate(bpm)']

# Plot histograms for numerical features
data[numerical_cols].hist(bins=30, figsize=(10, 7))
plt.show()

# %%
# Inspect column names
print(data.columns)

# Summary statistics
print(data.describe())

# Data types
print(data.dtypes)

# Missing values
print(data.isnull().sum())
# Out:
# Index(['Label', 'Time (s)', 'Sound pressure level (dB)', 'Music', 'Win',
#        'Heart rate(bpm)', 'Emotional state'],
#       dtype='object')
#               Label      Time (s)  Sound pressure level (dB)         Music  \
# count  25092.000000  25092.000000               24852.000000  25092.000000
# mean       2.642077    310.679885                 -55.787633      0.611549
# std        1.356158    211.389745                   8.559648      0.487408
# min        1.000000      0.000000                 -74.487855      0.000000
# 25%        1.000000    132.518004                 -61.800000      0.000000
# 50%        3.000000    280.598191                 -57.400000      1.000000
# 75%        4.000000    463.025101                 -50.900000      1.000000
# max        5.000000    825.725933                  -7.980000      1.000000
#
#            Win  Heart rate(bpm)
# count  25092.0     25092.000000
# mean       1.0        83.985812
# std        0.0         5.788016
# min        1.0        70.000000
# 25%        1.0        80.000000
# 50%        1.0        85.000000
# 75%        1.0        88.000000
# max        1.0        93.000000
# Label                          int64
# Time (s)                     float64
# Sound pressure level (dB)    float64
# Music                          int64
# Win                            int64
# Heart rate(bpm)                int64
# Emotional state               object
# dtype: object
# Label                          0
# Time (s)                       0
# Sound pressure level (dB)    240
# Music                          0
# Win                            0
# Heart rate(bpm)                0
# Emotional state                0
# dtype: int64

# %%
# Box plots for outlier detection
data[numerical_cols].plot(kind='box', subplots=True, layout=(1, len(numerical_cols)), figsize=(15, 5))
plt.show()

# %%
# Correlation matrix
corr_matrix = data[numerical_cols].corr()

# %%
# Heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.show()

# %%
# Time series plots
plt.figure(figsize=(12, 6))
plt.plot(data['Time (s)'], data['Sound pressure level (dB)'], label='Sound pressure level (dB)')
plt.plot(data['Time (s)'], data['Heart rate(bpm)'], label='Heart rate(bpm)')
plt.xlabel('Time (s)')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
# Distribution of categorical features
categorical_cols = ['Music', 'Win', 'Emotional state']

for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data[col].astype(str).str.strip())  # Convert to string and strip spaces if necessary
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Pair plot for numerical features
sns.pairplot(data[numerical_cols])
plt.show()

# %%
# Group by 'Win' and calculate mean for numerical features
grouped = data.groupby('Win')[numerical_cols].mean()
print(grouped)
# Out:
#        Time (s)  Sound pressure level (dB)  Heart rate(bpm)
# Win
# 1    310.679885                 -55.787633        83.985812

# %%
# Bar plot for grouped analysis
grouped.plot(kind='bar', figsize=(10, 6))
plt.title('Mean values of numerical features grouped by Win')
plt.show()
